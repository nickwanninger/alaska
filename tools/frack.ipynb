# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

# %%
# %matplotlib widget
df = pd.read_csv('../frack.csv', names=['timestamp', 'allocated', 'total_size'])
df['util'] = df['allocated'] / df['total_size']
sns.lineplot(data=df, x='timestamp', y='allocated')
sns.lineplot(data=df, x='timestamp', y='total_size')
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='allocated'>

# %%
sns.lineplot(data=df, x='timestamp', y='util')
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='util'>
