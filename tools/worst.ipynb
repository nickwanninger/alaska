# %% [markdown]
# ## This file is designed to display the output from test/worst.c

# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

# %%
df = pd.read_csv('../worst.csv')

sns.lineplot(df)
g = sns.displot(df['alaska'] / df['baseline'], kind="kde", label='slowdown', fill=True, height=3, aspect=2.5, cut=0, bw_adjust=.2)
g.set(xlim=(0, None), title="Slowdown")
g = sns.displot(df, kind="kde", fill=True, height=3, aspect=2.5, cut=0, bw_adjust=.4)
g.set(title="Nanoseconds Taken to walk a linked list")
# sns.displot(df, kind="ecdf", height=3, aspect=2.5)

# %%
df = pd.read_csv('../slowdown.csv')
sns.lineplot(df,x='nodesize',y='slowdown')
# Out:
# <AxesSubplot: xlabel='nodesize', ylabel='slowdown'>
