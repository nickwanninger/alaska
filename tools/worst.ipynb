# %% [markdown]
# ## This file is designed to display the output from test/worst.c

# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

# %%
df = pd.read_csv('../worst.csv')
display(df)
sns.displot(df['alaska'] / df['baseline'], kind="kde", label='slowdown', fill=True, height=3, aspect=2.5, cut=0, bw_adjust=1)
sns.displot(df, kind="kde", fill=True, height=3, aspect=2.5, cut=0, bw_adjust=1)
# sns.displot(df, kind="ecdf", height=3, aspect=2.5)
# Out:
#      baseline  alaska
# 0      136750  342542
# 1      134750  332917
# 2      134917  322708
# 3      134834  322626
# 4      135167  322625
# ..        ...     ...
# 995    140167  322708
# 996    141083  322709
# 997    142666  322875
# 998    145250  322792
# 999    143833  322667
#
# [1000 rows x 2 columns]
