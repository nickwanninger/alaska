# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

# %%
df = pd.read_csv('../runtime.log', names=['nanoseconds'], comment='#')

# df['microseconds'] = df['nanoseconds'] / 1000.0
# df['miliseconds'] = df['microseconds'] / 1000.0
g = sns.ecdfplot(df, x='nanoseconds')
g.set_xscale('log')
# g.
