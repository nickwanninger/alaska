# %% [markdown]
# ## This file is designed to display the output from test/grid.c

# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

# %%
base = pd.read_csv('../grid.base.csv')
df = pd.read_csv('../grid.csv')
df['time'] = df['time'] / base['time']


df = df.pivot(index='work', columns='nodes', values='time')
sns.heatmap(df)
# Out:
# <AxesSubplot: xlabel='nodes', ylabel='work'>
